# %% [markdown]
# ## Neural Network - Genetic Algorithm

# %%
import sklearn
import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.model_selection import train_test_split
pd.options.display.max_columns = None
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('figure', figsize=[12,5])
import mlrose_hiive
from sklearn.metrics import f1_score
from functools import partial

# %%
np.random.seed(1)
wine_dataset = pd.read_csv("wine_dataset.csv")
print(wine_dataset.info())
wine_dataset.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   class                    5000 non-null   int64
#  1   Alcohol                  5000 non-null   float64
#  2   Malic_acid               5000 non-null   float64
#  3   Ash                      5000 non-null   float64
#  4   Alcalinity_of_ash        5000 non-null   float64
#  5   Magnesium                5000 non-null   float64
#  6   Total_phenols            5000 non-null   float64
#  7   Flavanoids               5000 non-null   float64
#  8   Nonflavanoid_phenols     5000 non-null   float64
#  9   Proanthocyanins          5000 non-null   float64
#  10  Color_intensity          5000 non-null   float64
#  11  Hue                      5000 non-null   float64
#  12  Od_Hod_of_diluted_wines  5000 non-null   float64
#  13  Proline                  5000 non-null   float64
# dtypes: float64(13), int64(1)
# memory usage: 547.0 KB
# None
#    class    Alcohol  Malic_acid       Ash  Alcalinity_of_ash   Magnesium  \
# 0      1  13.761443    0.972960  2.191146          14.349954  106.525734
# 1      2  11.897923    1.297780  2.199666          17.478054  104.205421
# 2      3  12.659632    1.748552  2.438597          21.584696   88.079451
# 3      1  13.054828    1.817559  1.893926          15.390157  108.589893
# 4      3  11.769431    3.017528  3.013448          17.081528   86.525235
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0       2.288580    2.584551              0.418044         1.862804
# 1       2.716657    1.855066              0.318077         1.029640
# 2       1.919476    0.681341              0.538078         1.327974
# 3       2.662509    2.815723              0.278535         1.473812
# 4       2.224963    0.846229              0.286065         1.644007
#
#    Color_intensity       Hue  Od_Hod_of_diluted_wines     Proline
# 0         3.086808  1.169861                 2.819086  850.678431
# 1         9.103668  1.353718                 2.780333  332.922006
# 2         8.803633  0.643678                 1.569951  633.531687
# 3         6.386732  0.820398                 3.694865  880.103325
# 4        10.383464  0.734288                 2.747013  475.152492

# %%
from sklearn.preprocessing import MinMaxScaler

# Separating the target and the rest of the dataset
target = wine_dataset["class"]
wine_dataset.drop(columns=["class"], inplace=True)

# Scaling the data using MinMaxScaler
min_max_scaler = MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(wine_dataset)

# Transforming the scaled data back to a DataFrame
wine_dataset = pd.DataFrame(x_scaled, columns=wine_dataset.columns)

# Adding the target back to the dataset at the beginning
wine_dataset.insert(0, "class", target)

# Displaying the first few rows
wine_dataset.head(5)
# Out:
#    class   Alcohol  Malic_acid       Ash  Alcalinity_of_ash  Magnesium  \
# 0      1  0.726791    0.085805  0.432125           0.200468   0.392663
# 1      2  0.237919    0.142156  0.437079           0.357903   0.368467
# 2      3  0.437744    0.220358  0.576004           0.564587   0.200303
# 3      1  0.541419    0.232330  0.259309           0.252821   0.414189
# 4      3  0.204211    0.440507  0.910246           0.337946   0.184095
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0       0.452788    0.559874              0.477090         0.489749
# 1       0.599717    0.382811              0.322602         0.258369
# 2       0.326101    0.097921              0.662590         0.341220
# 3       0.581132    0.615985              0.261494         0.381721
# 4       0.430953    0.137943              0.273130         0.428986
#
#    Color_intensity       Hue  Od_Hod_of_diluted_wines   Proline
# 0         0.163244  0.635628                 0.584439  0.399009
# 1         0.665030  0.790293                 0.571170  0.065151
# 2         0.640008  0.192992                 0.156748  0.258989
# 3         0.438447  0.341653                 0.884296  0.417983
# 4         0.771760  0.269215                 0.559762  0.156864

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# Set up stratified sampling
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=30)

for train_ind, test_ind in split.split(wine_dataset, wine_dataset["class"]):
    train_set = wine_dataset.loc[train_ind]
    test_set = wine_dataset.loc[test_ind]

# Display dataset information
train_set.info()
test_set.info()

# Create X and Y for train and test set
train_X = train_set.drop("class", axis=1)
train_y = train_set["class"]
test_X = test_set.drop("class", axis=1)
test_y = test_set["class"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 1725 to 3709
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   class                    4000 non-null   int64
#  1   Alcohol                  4000 non-null   float64
#  2   Malic_acid               4000 non-null   float64
#  3   Ash                      4000 non-null   float64
#  4   Alcalinity_of_ash        4000 non-null   float64
#  5   Magnesium                4000 non-null   float64
#  6   Total_phenols            4000 non-null   float64
#  7   Flavanoids               4000 non-null   float64
#  8   Nonflavanoid_phenols     4000 non-null   float64
#  9   Proanthocyanins          4000 non-null   float64
#  10  Color_intensity          4000 non-null   float64
#  11  Hue                      4000 non-null   float64
#  12  Od_Hod_of_diluted_wines  4000 non-null   float64
#  13  Proline                  4000 non-null   float64
# dtypes: float64(13), int64(1)
# memory usage: 468.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 387 to 4415
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   class                    1000 non-null   int64
#  1   Alcohol                  1000 non-null   float64
#  2   Malic_acid               1000 non-null   float64
#  3   Ash                      1000 non-null   float64
#  4   Alcalinity_of_ash        1000 non-null   float64
#  5   Magnesium                1000 non-null   float64
#  6   Total_phenols            1000 non-null   float64
#  7   Flavanoids               1000 non-null   float64
#  8   Nonflavanoid_phenols     1000 non-null   float64
#  9   Proanthocyanins          1000 non-null   float64
#  10  Color_intensity          1000 non-null   float64
#  11  Hue                      1000 non-null   float64
#  12  Od_Hod_of_diluted_wines  1000 non-null   float64
#  13  Proline                  1000 non-null   float64
# dtypes: float64(13), int64(1)
# memory usage: 117.2 KB

# %%
# %%time

# Define the scorer
f1_labs = partial(f1_score, average="weighted")

# Define the parameters for grid search
grid_search_parameters = ({
    'learning_rate': [0.01, 0.1],  # specify the learning rates
    'mutation_prob': [0.1, 0.25],  # specify the mutation probabilities
    'pop_size': [200],
    'activation': [mlrose_hiive.neural.activation.relu],
    'max_iters': [10000],
    'bias': [True],
    'is_classifier': [True],
    'early_stopping': [True],
    'max_attempts': [100]
})

# Initialize the NNGSRunner with the parameters
ga_nn = mlrose_hiive.NNGSRunner(
    x_train=train_X,
    y_train=pd.get_dummies(train_y.values.ravel()).values,
    x_test=test_X,
    y_test=pd.get_dummies(test_y.values.ravel()).values,
    experiment_name="NeuralNetworkGA",
    output_directory="./ga",
    seed=10,
    iteration_list=[10000],
    algorithm=mlrose_hiive.algorithms.ga.genetic_alg,
    hidden_layer_sizes=[[60, 60]],
    grid_search_parameters=grid_search_parameters,
    grid_search_scorer_method=f1_labs,
    n_jobs=-2
)

# Train and search for the best hyperparameters
result = ga_nn.run()
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Wall time: 1h 20min 12s

# %%
print(pd.DataFrame(result[0]).columns)
print(pd.DataFrame(result[1]).columns)
print(pd.DataFrame(result[2]).columns)
# Out:
# Index(['Iteration', 'Fitness', 'FEvals', 'Time', 'State', 'max_iters',
#        'learning_rate', 'mutation_prob', 'pop_size', 'is_classifier',
#        'init_state', 'algorithm', 'activation', 'bias', 'early_stopping',
#        'clip_max', 'hidden_layer_sizes', 'learning_rate_init', 'max_attempts'],
#       dtype='object')
# Index(['Iteration', 'Time', 'Fitness', 'FEvals', 'max_iters', 'learning_rate',
#        'mutation_prob', 'pop_size', 'is_classifier', 'init_state', 'algorithm',
#        'activation', 'bias', 'early_stopping', 'clip_max',
#        'hidden_layer_sizes', 'learning_rate_init', 'max_attempts'],
#       dtype='object')
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_activation', 'param_bias', 'param_early_stopping',
#        'param_hidden_layer_sizes', 'param_is_classifier',
#        'param_learning_rate', 'param_max_attempts', 'param_max_iters',
#        'param_mutation_prob', 'param_pop_size', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'split3_test_score',
#        'split4_test_score', 'mean_test_score', 'std_test_score',
#        'rank_test_score', 'split0_train_score', 'split1_train_score',
#        'split2_train_score', 'split3_train_score', 'split4_train_score',
#        'mean_train_score', 'std_train_score'],
#       dtype='object')

# %%
# Convert the result to a dataframe
results_df = pd.DataFrame(result[0])

# Displaying the parameters and their respective fitness/performance
for index, row in results_df.iterrows():
    print("Parameters and Performance:")
    print(f"  Learning Rate: {row['learning_rate']}")
    print(f"  Mutation Probability: {row['mutation_prob']}")
    print(f"  Population Size: {row['pop_size']}")
    print(f"  Activation: {row['activation']}")
    print(f"  Fitness (Error/Loss value): {row['Fitness']}")
    print(f"  Iteration: {row['Iteration']}")
    print(f"  Evaluation Function Calls (FEvals): {row['FEvals']}")
    print(f"  Time Taken: {row['Time']} seconds")
    print("---------------------------")

# Plotting the performance:
import matplotlib.pyplot as plt

# Plot Fitness over Iterations
plt.figure(figsize=(10,6))
plt.plot(results_df['Iteration'], results_df['Fitness'], marker='o')
plt.title('Fitness over Iterations')
plt.xlabel('Iterations')
plt.ylabel('Fitness (Error/Loss Value)')
plt.grid(True)
plt.show()
# Out:
# Parameters and Performance:
#   Learning Rate: 0.01
#   Mutation Probability: 0.1
#   Population Size: 200
#   Activation: relu
#   Fitness (Error/Loss value): 22.44156996259321
#   Iteration: 0
#   Evaluation Function Calls (FEvals): 201
#   Time Taken: 3.4697065000000293 seconds
# ---------------------------
# Parameters and Performance:
#   Learning Rate: 0.01
#   Mutation Probability: 0.1
#   Population Size: 200
#   Activation: relu
#   Fitness (Error/Loss value): 7.840302241644726
#   Iteration: 10000
#   Evaluation Function Calls (FEvals): 55081
#   Time Taken: 996.1808637000013 seconds
# ---------------------------

# %%
# Convert the result to a dataframe
results_df = pd.DataFrame(result[0])

# Find the row with the best (minimum) fitness
best_row = results_df.loc[results_df['Fitness'].idxmin()]

print("Best Parameters and Performance:")
print(f"  Learning Rate: {best_row['learning_rate']}")
print(f"  Mutation Probability: {best_row['mutation_prob']}")
print(f"  Population Size: {best_row['pop_size']}")
print(f"  Activation: {best_row['activation']}")
print(f"  Best Fitness (Error/Loss value): {best_row['Fitness']}")
print(f"  Iteration: {best_row['Iteration']}")
print(f"  Evaluation Function Calls (FEvals): {best_row['FEvals']}")
print(f"  Time Taken: {best_row['Time']} seconds")
# Out:
# Best Parameters and Performance:
#   Learning Rate: 0.01
#   Mutation Probability: 0.1
#   Population Size: 200
#   Activation: relu
#   Best Fitness (Error/Loss value): 7.840302241644726
#   Iteration: 10000
#   Evaluation Function Calls (FEvals): 55081
#   Time Taken: 996.1808637000013 seconds

# %%
# 1. Convert the results to a DataFrame.
results_df = pd.DataFrame(result[1])

# 2. Identify the best parameter set based on the minimum fitness.
best_row = results_df.loc[results_df['Fitness'].idxmin()]

# 3. Filter the results for the best parameter set.
best_params_data = results_df[
    (results_df['learning_rate'] == best_row['learning_rate']) &
    (results_df['mutation_prob'] == best_row['mutation_prob']) &
    (results_df['pop_size'] == best_row['pop_size']) &
    (results_df['activation'] == best_row['activation']) &
    (results_df['max_iters'] == best_row['max_iters']) &
    (results_df['bias'] == best_row['bias']) &
    (results_df['is_classifier'] == best_row['is_classifier']) &
    (results_df['early_stopping'] == best_row['early_stopping']) &
    (results_df['max_attempts'] == best_row['max_attempts'])
]

# 4. Compute the metrics based on the filtered data.
print(f"Genetic Algorithm Neural Network - Results for Best Parameters (Learning Rate: {best_row['learning_rate']}, Mutation Prob: {best_row['mutation_prob']}, Population Size: {best_row['pop_size']}, Activation: {best_row['activation']}, Max Iters: {best_row['max_iters']}):")
print("--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
print("Average Fitness:", best_params_data.Fitness.mean())
print("Maximum Fitness:", best_params_data.Fitness.max())
print("Average Time for an Iteration:", best_params_data.Time.mean())
print("\n")
# Out:
# Genetic Algorithm Neural Network - Results for Best Parameters (Learning Rate: 0.01, Mutation Prob: 0.1, Population Size: 200, Activation: relu, Max Iters: 10000):
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Average Fitness: 8.566561950401193
# Maximum Fitness: 14.057281992728647
# Average Time for an Iteration: 499.33792713175217

# %%
# Assuming the results contains curve data for GA
ga_run_curves = pd.DataFrame(result[1])

# Find the parameters corresponding to the run with the highest fitness value for GA
best_params_ga = ga_run_curves.iloc[ga_run_curves.Fitness.idxmax()]

# Get parameters corresponding to the best run
best_learning_rate_ga = best_params_ga['learning_rate']
best_mutation_prob_ga = best_params_ga['mutation_prob']

# Filter the curves to only include data from the best GA run
best_ga_curve = ga_run_curves[(ga_run_curves['learning_rate'] == best_learning_rate_ga) & 
                              (ga_run_curves['mutation_prob'] == best_mutation_prob_ga)]

# Plotting the best GA curve's fitness over iterations
ax_ga = best_ga_curve.Fitness.plot(lw=2, 
                                   color='blue',   # Set the line color to purple for distinction
                                   marker='.', 
                                   markersize=2, 
                                   figsize=(12,8), 
                                   grid=True,      # Enable grid
                                   title='Best GA')

# Set x-axis label with increased font size
ax_ga.set_xlabel("Iterations", fontsize=14)

# Set y-axis label with increased font size
ax_ga.set_ylabel("Value", fontsize=14)

# Set the title's font size larger
ax_ga.set_title('Best GA', fontsize=16)

# Set grid appearance to grey and dotted
ax_ga.grid(True, linestyle='--', which='both', color='grey', alpha=.7)

# %%
# Importing required metrics
from sklearn.metrics import classification_report

# Predicting the test set results using the trained model
y_pred = result[3].predict(test_X)

# Converting ground truth labels to one-hot encoded format
y_true_one_hot = pd.get_dummies(test_y.values.ravel()).values

# Printing the classification report
print(classification_report(y_true_one_hot, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.77      0.75       315
#            1       0.81      0.78      0.80       403
#            2       0.74      0.72      0.73       282
#
#    micro avg       0.76      0.76      0.76      1000
#    macro avg       0.76      0.76      0.76      1000
# weighted avg       0.76      0.76      0.76      1000
#  samples avg       0.76      0.76      0.76      1000

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_true_one_hot.argmax(axis=1), y_pred.argmax(axis=1))
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
result[2]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0    1486.323981    641.344511         0.010775        0.001324
# 1     978.950503    192.904841         0.009774        0.001466
# 2    1370.443370    454.655284         0.007196        0.002201
# 3     949.134507    204.313096         0.007380        0.002570
#
#   param_activation  param_bias  param_early_stopping param_hidden_layer_sizes  \
# 0             relu        True                  True                 [60, 60]
# 1             relu        True                  True                 [60, 60]
# 2             relu        True                  True                 [60, 60]
# 3             relu        True                  True                 [60, 60]
#
#    param_is_classifier  param_learning_rate  param_max_attempts  \
# 0                 True                 0.01                 100
# 1                 True                 0.01                 100
# 2                 True                 0.10                 100
# 3                 True                 0.10                 100
#
#    param_max_iters  param_mutation_prob  param_pop_size  \
# 0            10000                 0.10             200
# 1            10000                 0.25             200
# 2            10000                 0.10             200
# 3            10000                 0.25             200
#
#                                               params  split0_test_score  \
# 0  {'activation': <function relu at 0x000001C1B47...           0.786013
# 1  {'activation': <function relu at 0x000001C1B47...           0.733876
# 2  {'activation': <function relu at 0x000001C1B47...           0.786013
# 3  {'activation': <function relu at 0x000001C1B47...           0.733876
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.669011           0.829367           0.755355           0.790104
# 1           0.729768           0.757743           0.773754           0.703937
# 2           0.669011           0.829367           0.755355           0.790104
# 3           0.729768           0.757743           0.773754           0.703937
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.765970        0.053883                1            0.786645
# 1         0.739816        0.024069                3            0.725821
# 2         0.765970        0.053883                1            0.786645
# 3         0.739816        0.024069                3            0.725821
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0            0.685869            0.815557            0.775416
# 1            0.745205            0.724901            0.754279
# 2            0.685869            0.815557            0.775416
# 3            0.745205            0.724901            0.754279
#
#    split4_train_score  mean_train_score  std_train_score
# 0            0.798411          0.772380         0.045252
# 1            0.710519          0.732145         0.015624
# 2            0.798411          0.772380         0.045252
# 3            0.710519          0.732145         0.015624
