# %%
import gym
import numpy as np
import random
from timeit import default_timer as timer
from datetime import timedelta
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns

# %%
from gym.envs.toy_text.frozen_lake import generate_random_map, FrozenLakeEnv
np.random.seed(2)
sixteen = generate_random_map(16)
np.random.seed(44)
tvelve = generate_random_map(12)
MAPS = {
    "4x4": [
        "SFFF",
        "FHFH",
        "FFFH",
        "HFFG"
    ],
    "8x8": [
        "SFFFFFFF",
        "FFFFFFFF",
        "FFFHFFFF",
        "FFFFFHFF",
        "FFFHFFFF",
        "FHHFFFHF",
        "FHFFHFHF",
        "FFFHFFFG"
    ],
    "12x12": tvelve,
    "16x16": sixteen
}

# %%
def test_policy(env, policy, n_epoch=1000):
    rewards = []
    episode_counts = []
    for i in range(n_epoch):
        current_state_tuple = env.reset()
        current_state = current_state_tuple[0] if isinstance(current_state_tuple, tuple) else current_state_tuple

        ep = 0
        done = False
        episode_reward = 0
        while not done and ep < 1000:
            ep += 1
            action = int(policy[current_state])
            step_result = env.step(action)

            # Handle different lengths of step_result
            new_state_tuple = step_result[0]
            reward = step_result[1]
            done = step_result[2]
            new_state = new_state_tuple[0] if isinstance(new_state_tuple, tuple) else new_state_tuple

            episode_reward += reward
            current_state = new_state

        rewards.append(episode_reward)
        episode_counts.append(ep)

    mean_reward = sum(rewards)/len(rewards)
    mean_eps = sum(episode_counts)/len(episode_counts)
    return mean_reward, mean_eps, rewards, episode_counts

# %%
def value_iteration(env, discount=0.9, epsilon=1e-9):
    
    start = timer()
    
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    policy = np.zeros((1, number_of_states))
#     policy = np.zeros(number_of_states, dtype=int)
    value_list = np.zeros((1, number_of_states))
    old_value_list = value_list.copy()
    episode = 0
    max_change = 1
    sigma = discount
    while max_change > epsilon:
        episode += 1
        for s in range(number_of_states):
            assigned_value = -np.inf
            for a in range(number_of_actions):
                # get new state and its reward        
                total_cand_value = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    # get new states value
                    value_new_state = old_value_list[0][new_state]
                    cand_value = 0
                    if done:
                        cand_value = reward 
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_cand_value += cand_value*prob 
                        
                if total_cand_value > assigned_value:
                    assigned_value = total_cand_value
                    policy[0][s] = a
                    value_list[0][s] = assigned_value
        changes = np.abs(value_list - old_value_list)
        max_change = np.max(changes)
        old_value_list = value_list.copy()
        
    end = timer()
    time_spent = timedelta(seconds=end-start)
    print("Solved in: {} episodes and {} seconds".format(episode, time_spent))
    return policy[0], episode, time_spent

# %%
def policy_iteration(env, discount=0.9, epsilon=1e-9):
    
    start = timer()
    
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    ## 1
    policy = np.random.randint(number_of_actions, size=(1,number_of_states))
#     policy = np.random.randint(number_of_actions, size=number_of_states)
#     policy = np.zeros((1,number_of_states))
    value_list = np.zeros((1, number_of_states))
    episode = 0
    sigma = discount
    
    ## 2
    policy_stable = False
    while not policy_stable:
        episode += 1
        eval_acc = True
        while eval_acc:
            eps = 0
            for s in range(number_of_states):
                # first row
                v = value_list[0][s]

                # get the new value 
                a = policy[0][s]
                total_val_new_state = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    value_new_state = value_list[0][new_state]
                    # second row
                    cand_value = 0
                    if done:
                        cand_value = reward                     
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_val_new_state += cand_value*prob 
                value_list[0][s] = total_val_new_state
                    
                # third row
                eps = max(eps, np.abs(v-value_list[0][s]))
            if eps < epsilon:
                eval_acc = False


        ## 3
        policy_stable = True
        for s in range(number_of_states):

            # assign 
            old_action = policy[0][s]
            # get the argmax a here
            max_value = -np.inf
            for a in range(number_of_actions):
                # get the new value 
                total_cand_value = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    value_new_state = value_list[0][new_state]
                    cand_value = 0
                    if done:
                        cand_value = reward
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_cand_value += prob*cand_value
                if total_cand_value > max_value:
                    max_value = total_cand_value
                    policy[0][s] = a

            # if old-action != policy[s]
            if old_action != policy[0][s]:
                policy_stable = False
    
    
    end = timer()
    time_spent = timedelta(seconds=end-start)
    print("Solved in: {} episodes and {} seconds".format(episode, time_spent))
    return policy[0], episode, time_spent

# %%
def train_and_test_pi_vi(env, discount=[0.9], epsilon=[1e-9], mute=False):
    vi_dict = {}
    pi_dict = {}

    for dis in discount:
        vi_dict[dis] = {}
        pi_dict[dis] = {}
        for eps in epsilon:
            # Run Value Iteration
            print(f"Running Value Iteration - Discount: {dis}, Epsilon: {eps}")
            vi_policy, vi_solve_iter, vi_solve_time = value_iteration(env, dis, eps)
            vi_mrews, vi_meps, _, __ = test_policy(env, vi_policy)
            vi_dict[dis][eps] = {
                "mean_reward": vi_mrews,
                "mean_eps": vi_meps,
                "iteration": vi_solve_iter,
                "time_spent": vi_solve_time,
                "policy": vi_policy
            }
            if not mute:
                print(f"Results - Value Iteration: Discount: {dis}, Epsilon: {eps}")
                print(f"Solved in: {vi_solve_iter} episodes, Time: {vi_solve_time}")
                print(f"Mean Reward: {vi_mrews}, Mean Episodes: {vi_meps}\n")

            # Run Policy Iteration
            print(f"Running Policy Iteration - Discount: {dis}, Epsilon: {eps}")
            pi_policy, pi_solve_iter, pi_solve_time = policy_iteration(env, dis, eps)
            pi_mrews, pi_meps, _, __ = test_policy(env, pi_policy)
            pi_dict[dis][eps] = {
                "mean_reward": pi_mrews,
                "mean_eps": pi_meps,
                "iteration": pi_solve_iter,
                "time_spent": pi_solve_time,
                "policy": pi_policy
            }
            if not mute:
                print(f"Results - Policy Iteration: Discount: {dis}, Epsilon: {eps}")
                print(f"Solved in: {pi_solve_iter} episodes, Time: {pi_solve_time}")
                print(f"Mean Reward: {pi_mrews}, Mean Episodes: {pi_meps}\n")

    return vi_dict, pi_dict

# %%
def map_discretize(the_map):
    size = len(the_map)
    dis_map = np.zeros((size,size))
    for i, row in enumerate(the_map):
        for j, loc in enumerate(row):
            if loc == "S":
                dis_map[i, j] = 0
            elif loc == "F":
                dis_map[i, j] = 0
            elif loc == "H":
                dis_map[i, j] = -1
            elif loc == "G":
                dis_map[i, j] = 1
    return dis_map


def policy_numpy(policy):
    size = int(np.sqrt(len(policy)))
    pol = np.asarray(policy)
    pol = pol.reshape((size, size))
    return pol


def see_policy(map_size, policy):
    map_name = str(map_size)+"x"+str(map_size)
    data = map_discretize(MAPS[map_name])
    np_pol = policy_numpy(policy)
    plt.figure(figsize=(6, 6))
    plt.imshow(data, interpolation="nearest")

    for i in range(np_pol[0].size):
        for j in range(np_pol[0].size):
            arrow = '\u2190'
            if np_pol[i, j] == 1:
                arrow = '\u2193'
            elif np_pol[i, j] == 2:
                arrow = '\u2192'
            elif np_pol[i, j] == 3:
                arrow = '\u2191'
            text = plt.text(j, i, arrow,
                           ha="center", va="center", color="w")
    plt.show()

# %%
def plot_the_dict(dictionary, value="Score", size=4, variable="Discount Rate", log=False):

    plt.figure(figsize=(12, 8))
    title = "Average and Max {} on {}x{} Frozen Lake".format(value, size, size)
    the_val = value
    value = "Average {}".format(the_val)
    val_type = "Type of {}".format(the_val)
    the_df = pd.DataFrame(columns=[variable, value, val_type])
    for k, v in dictionary.items():
        for val in v:
            if not log:
                dic = {variable: k, value: float(val), val_type: "Average with std"}
            else:
                dic = {variable: np.log10(k), value: float(val), val_type: "Average with std"}                
            the_df = the_df.append(dic, ignore_index=True)
        if not log:
            dic = {variable: k, value: float(max(v)), val_type: "Max"}
        else:
            dic = {variable: np.log10(k), value: float(max(v)), val_type: "Max"}
        the_df = the_df.append(dic, ignore_index=True)
    
    # Set the font size for axis titles
    plt.xlabel(variable, fontsize=12)
    plt.ylabel(value, fontsize=12)
    
    sns.lineplot(x=variable, y=value, hue=val_type, style=val_type, markers=True, data=the_df).set(title=title)

# %%
def convert_dict_to_dict(the_dict):
    
    # return for discount
    discount_rewards = {}
    discount_iterations = {}
    discount_times = {}


    for disc in the_dict:
        discount_rewards[disc] = []    
        discount_iterations[disc] = []    
        discount_times[disc] = []

        for eps in the_dict[disc]:
            discount_rewards[disc].append(the_dict[disc][eps]['mean_reward'])
            discount_iterations[disc].append(the_dict[disc][eps]['iteration'])        
            discount_times[disc].append(the_dict[disc][eps]['time_spent'].total_seconds())  

            
    epsilon_rewards = {}
    epsilon_iterations = {}
    epsilon_times = {}
    for eps in the_dict[0.5]:
        epsilon_rewards[eps] = []    
        epsilon_iterations[eps] = []    
        epsilon_times[eps] = []
    
        for disc in vi_dict:
            epsilon_rewards[eps].append(the_dict[disc][eps]['mean_reward'])
            epsilon_iterations[eps].append(the_dict[disc][eps]['iteration'])        
            epsilon_times[eps].append(the_dict[disc][eps]['time_spent'].total_seconds()) 
            
    return discount_rewards, discount_iterations, discount_times, epsilon_rewards, epsilon_iterations, epsilon_times

# %% [markdown]
# ## 4x4

# %%
env = gym.make("FrozenLake-v1")
vi_dict, pi_dict = train_and_test_pi_vi(env, discount=[0.5, 0.75, 0.9, 0.95, 0.99, 0.9999], 
                                        epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], mute=False)
# Out:
# Running Value Iteration - Discount: 0.5, Epsilon: 0.001
# Solved in: 7 episodes and 0:00:00.004215 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 0.001
# Solved in: 7 episodes, Time: 0:00:00.004215
# Mean Reward: 0.469, Mean Episodes: 26.987
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 0.001
# Solved in: 6 episodes and 0:00:00.002923 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 0.001
# Solved in: 6 episodes, Time: 0:00:00.002923
# Mean Reward: 0.441, Mean Episodes: 27.475
#
# Running Value Iteration - Discount: 0.5, Epsilon: 1e-06
# Solved in: 16 episodes and 0:00:00.006259 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 1e-06
# Solved in: 16 episodes, Time: 0:00:00.006259
# Mean Reward: 0.448, Mean Episodes: 29.08
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 1e-06
# Solved in: 5 episodes and 0:00:00.005438 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 1e-06
# Solved in: 5 episodes, Time: 0:00:00.005438
# Mean Reward: 0.464, Mean Episodes: 27.35
#
# Running Value Iteration - Discount: 0.5, Epsilon: 1e-09
# Solved in: 25 episodes and 0:00:00.008620 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 1e-09
# Solved in: 25 episodes, Time: 0:00:00.008620
# Mean Reward: 0.439, Mean Episodes: 27.966
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 1e-09
# Solved in: 6 episodes and 0:00:00.009607 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 1e-09
# Solved in: 6 episodes, Time: 0:00:00.009607
# Mean Reward: 0.448, Mean Episodes: 27.83
#
# Running Value Iteration - Discount: 0.5, Epsilon: 1e-12
# Solved in: 34 episodes and 0:00:00.010716 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 1e-12
# Solved in: 34 episodes, Time: 0:00:00.010716
# Mean Reward: 0.422, Mean Episodes: 27.706
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 1e-12
# Solved in: 8 episodes and 0:00:00.009983 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 1e-12
# Solved in: 8 episodes, Time: 0:00:00.009983
# Mean Reward: 0.478, Mean Episodes: 27.452
#
# Running Value Iteration - Discount: 0.5, Epsilon: 1e-15
# Solved in: 44 episodes and 0:00:00.012133 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 1e-15
# Solved in: 44 episodes, Time: 0:00:00.012133
# Mean Reward: 0.48, Mean Episodes: 27.231
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 1e-15
# Solved in: 4 episodes and 0:00:00.014033 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 1e-15
# Solved in: 4 episodes, Time: 0:00:00.014033
# Mean Reward: 0.45, Mean Episodes: 27.916
#
# Running Value Iteration - Discount: 0.75, Epsilon: 0.001
# Solved in: 12 episodes and 0:00:00.003498 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 0.001
# Solved in: 12 episodes, Time: 0:00:00.003498
# Mean Reward: 0.479, Mean Episodes: 27.25
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 0.001
# Solved in: 4 episodes and 0:00:00.003921 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 0.001
# Solved in: 4 episodes, Time: 0:00:00.003921
# Mean Reward: 0.447, Mean Episodes: 27.517
#
# Running Value Iteration - Discount: 0.75, Epsilon: 1e-06
# Solved in: 33 episodes and 0:00:00.011438 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 1e-06
# Solved in: 33 episodes, Time: 0:00:00.011438
# Mean Reward: 0.447, Mean Episodes: 27.315
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 1e-06
# Solved in: 4 episodes and 0:00:00.008174 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 1e-06
# Solved in: 4 episodes, Time: 0:00:00.008174
# Mean Reward: 0.469, Mean Episodes: 28.074
#
# Running Value Iteration - Discount: 0.75, Epsilon: 1e-09
# Solved in: 53 episodes and 0:00:00.017688 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 1e-09
# Solved in: 53 episodes, Time: 0:00:00.017688
# Mean Reward: 0.442, Mean Episodes: 27.084
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 1e-09
# Solved in: 4 episodes and 0:00:00.018102 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 1e-09
# Solved in: 4 episodes, Time: 0:00:00.018102
# Mean Reward: 0.457, Mean Episodes: 27.576
#
# Running Value Iteration - Discount: 0.75, Epsilon: 1e-12
# Solved in: 73 episodes and 0:00:00.022544 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 1e-12
# Solved in: 73 episodes, Time: 0:00:00.022544
# Mean Reward: 0.463, Mean Episodes: 28.615
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 1e-12
# Solved in: 6 episodes and 0:00:00.019906 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 1e-12
# Solved in: 6 episodes, Time: 0:00:00.019906
# Mean Reward: 0.476, Mean Episodes: 27.537
#
# Running Value Iteration - Discount: 0.75, Epsilon: 1e-15
# Solved in: 94 episodes and 0:00:00.047989 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 1e-15
# Solved in: 94 episodes, Time: 0:00:00.047989
# Mean Reward: 0.431, Mean Episodes: 27.792
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 1e-15
# Solved in: 3 episodes and 0:00:00.023874 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 1e-15
# Solved in: 3 episodes, Time: 0:00:00.023874
# Mean Reward: 0.468, Mean Episodes: 26.843
#
# Running Value Iteration - Discount: 0.9, Epsilon: 0.001
# Solved in: 27 episodes and 0:00:00.010943 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 0.001
# Solved in: 27 episodes, Time: 0:00:00.010943
# Mean Reward: 0.812, Mean Episodes: 45.203
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 0.001
# Solved in: 3 episodes and 0:00:00.005778 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 0.001
# Solved in: 3 episodes, Time: 0:00:00.005778
# Mean Reward: 0.782, Mean Episodes: 42.838
#
# Running Value Iteration - Discount: 0.9, Epsilon: 1e-06
# Solved in: 78 episodes and 0:00:00.021545 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 1e-06
# Solved in: 78 episodes, Time: 0:00:00.021545
# Mean Reward: 0.783, Mean Episodes: 43.904
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 1e-06
# Solved in: 6 episodes and 0:00:00.021284 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 1e-06
# Solved in: 6 episodes, Time: 0:00:00.021284
# Mean Reward: 0.802, Mean Episodes: 43.618
#
# Running Value Iteration - Discount: 0.9, Epsilon: 1e-09
# Solved in: 129 episodes and 0:00:00.040595 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 1e-09
# Solved in: 129 episodes, Time: 0:00:00.040595
# Mean Reward: 0.774, Mean Episodes: 44.651
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 1e-09
# Solved in: 3 episodes and 0:00:00.024575 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 1e-09
# Solved in: 3 episodes, Time: 0:00:00.024575
# Mean Reward: 0.801, Mean Episodes: 43.619
#
# Running Value Iteration - Discount: 0.9, Epsilon: 1e-12
# Solved in: 179 episodes and 0:00:00.061595 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 1e-12
# Solved in: 179 episodes, Time: 0:00:00.061595
# Mean Reward: 0.793, Mean Episodes: 44.573
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 1e-12
# Solved in: 2 episodes and 0:00:00.032076 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 1e-12
# Solved in: 2 episodes, Time: 0:00:00.032076
# Mean Reward: 0.781, Mean Episodes: 42.296
#
# Running Value Iteration - Discount: 0.9, Epsilon: 1e-15
# Solved in: 230 episodes and 0:00:00.074517 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 1e-15
# Solved in: 230 episodes, Time: 0:00:00.074517
# Mean Reward: 0.779, Mean Episodes: 41.169
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 1e-15
# Solved in: 4 episodes and 0:00:00.076804 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 1e-15
# Solved in: 4 episodes, Time: 0:00:00.076804
# Mean Reward: 0.769, Mean Episodes: 45.384
#
# Running Value Iteration - Discount: 0.95, Epsilon: 0.001
# Solved in: 44 episodes and 0:00:00.016428 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 0.001
# Solved in: 44 episodes, Time: 0:00:00.016428
# Mean Reward: 0.798, Mean Episodes: 43.671
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 0.001
# Solved in: 3 episodes and 0:00:00.018367 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 0.001
# Solved in: 3 episodes, Time: 0:00:00.018367
# Mean Reward: 0.776, Mean Episodes: 44.619
#
# Running Value Iteration - Discount: 0.95, Epsilon: 1e-06
# Solved in: 128 episodes and 0:00:00.041609 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 1e-06
# Solved in: 128 episodes, Time: 0:00:00.041609
# Mean Reward: 0.79, Mean Episodes: 43.949
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 1e-06
# Solved in: 6 episodes and 0:00:00.032993 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 1e-06
# Solved in: 6 episodes, Time: 0:00:00.032993
# Mean Reward: 0.793, Mean Episodes: 45.18
#
# Running Value Iteration - Discount: 0.95, Epsilon: 1e-09
# Solved in: 213 episodes and 0:00:00.071699 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 1e-09
# Solved in: 213 episodes, Time: 0:00:00.071699
# Mean Reward: 0.782, Mean Episodes: 42.847
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 1e-09
# Solved in: 4 episodes and 0:00:00.057477 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 1e-09
# Solved in: 4 episodes, Time: 0:00:00.057477
# Mean Reward: 0.781, Mean Episodes: 43.238
#
# Running Value Iteration - Discount: 0.95, Epsilon: 1e-12
# Solved in: 297 episodes and 0:00:00.099248 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 1e-12
# Solved in: 297 episodes, Time: 0:00:00.099248
# Mean Reward: 0.788, Mean Episodes: 44.687
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 1e-12
# Solved in: 5 episodes and 0:00:00.070180 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 1e-12
# Solved in: 5 episodes, Time: 0:00:00.070180
# Mean Reward: 0.79, Mean Episodes: 42.441
#
# Running Value Iteration - Discount: 0.95, Epsilon: 1e-15
# Solved in: 381 episodes and 0:00:00.167475 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 1e-15
# Solved in: 381 episodes, Time: 0:00:00.167475
# Mean Reward: 0.778, Mean Episodes: 42.894
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 1e-15
# Solved in: 4 episodes and 0:00:00.090742 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 1e-15
# Solved in: 4 episodes, Time: 0:00:00.090742
# Mean Reward: 0.791, Mean Episodes: 43.488
#
# Running Value Iteration - Discount: 0.99, Epsilon: 0.001
# Solved in: 105 episodes and 0:00:00.039307 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 0.001
# Solved in: 105 episodes, Time: 0:00:00.039307
# Mean Reward: 0.823, Mean Episodes: 47.584
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 0.001
# Solved in: 4 episodes and 0:00:00.016697 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 0.001
# Solved in: 4 episodes, Time: 0:00:00.016697
# Mean Reward: 0.813, Mean Episodes: 49.892
#
# Running Value Iteration - Discount: 0.99, Epsilon: 1e-06
# Solved in: 305 episodes and 0:00:00.100183 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 1e-06
# Solved in: 305 episodes, Time: 0:00:00.100183
# Mean Reward: 0.824, Mean Episodes: 47.394
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 1e-06
# Solved in: 7 episodes and 0:00:00.146603 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 1e-06
# Solved in: 7 episodes, Time: 0:00:00.146603
# Mean Reward: 0.799, Mean Episodes: 47.616
#
# Running Value Iteration - Discount: 0.99, Epsilon: 1e-09
# Solved in: 504 episodes and 0:00:00.196431 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 1e-09
# Solved in: 504 episodes, Time: 0:00:00.196431
# Mean Reward: 0.808, Mean Episodes: 45.784
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 1e-09
# Solved in: 4 episodes and 0:00:00.127806 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 1e-09
# Solved in: 4 episodes, Time: 0:00:00.127806
# Mean Reward: 0.819, Mean Episodes: 47.526
#
# Running Value Iteration - Discount: 0.99, Epsilon: 1e-12
# Solved in: 704 episodes and 0:00:00.553295 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 1e-12
# Solved in: 704 episodes, Time: 0:00:00.553295
# Mean Reward: 0.835, Mean Episodes: 50.884
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 1e-12
# Solved in: 5 episodes and 0:00:00.370068 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 1e-12
# Solved in: 5 episodes, Time: 0:00:00.370068
# Mean Reward: 0.819, Mean Episodes: 48.06
#
# Running Value Iteration - Discount: 0.99, Epsilon: 1e-15
# Solved in: 903 episodes and 0:00:00.267922 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 1e-15
# Solved in: 903 episodes, Time: 0:00:00.267922
# Mean Reward: 0.807, Mean Episodes: 47.407
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 1e-15
# Solved in: 4 episodes and 0:00:00.192073 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 1e-15
# Solved in: 4 episodes, Time: 0:00:00.192073
# Mean Reward: 0.841, Mean Episodes: 48.874
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 0.001
# Solved in: 149 episodes and 0:00:00.049088 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 0.001
# Solved in: 149 episodes, Time: 0:00:00.049088
# Mean Reward: 0.836, Mean Episodes: 50.617
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 0.001
# Solved in: 4 episodes and 0:00:00.042231 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 0.001
# Solved in: 4 episodes, Time: 0:00:00.042231
# Mean Reward: 0.828, Mean Episodes: 47.177
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 1e-06
# Solved in: 429 episodes and 0:00:00.171434 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 1e-06
# Solved in: 429 episodes, Time: 0:00:00.171434
# Mean Reward: 0.818, Mean Episodes: 47.796
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 1e-06
# Solved in: 6 episodes and 0:00:00.113591 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 1e-06
# Solved in: 6 episodes, Time: 0:00:00.113591
# Mean Reward: 0.793, Mean Episodes: 48.732
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 1e-09
# Solved in: 709 episodes and 0:00:00.245941 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 1e-09
# Solved in: 709 episodes, Time: 0:00:00.245941
# Mean Reward: 0.831, Mean Episodes: 48.454
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 1e-09
# Solved in: 7 episodes and 0:00:00.193368 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 1e-09
# Solved in: 7 episodes, Time: 0:00:00.193368
# Mean Reward: 0.823, Mean Episodes: 50.494
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 1e-12
# Solved in: 989 episodes and 0:00:00.422101 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 1e-12
# Solved in: 989 episodes, Time: 0:00:00.422101
# Mean Reward: 0.836, Mean Episodes: 49.95
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 1e-12
# Solved in: 6 episodes and 0:00:00.249924 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 1e-12
# Solved in: 6 episodes, Time: 0:00:00.249924
# Mean Reward: 0.828, Mean Episodes: 49.854
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 1e-15
# Solved in: 1266 episodes and 0:00:00.454873 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 1e-15
# Solved in: 1266 episodes, Time: 0:00:00.454873
# Mean Reward: 0.816, Mean Episodes: 48.081
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 1e-15
# Solved in: 4 episodes and 0:00:00.322996 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 1e-15
# Solved in: 4 episodes, Time: 0:00:00.322996
# Mean Reward: 0.834, Mean Episodes: 47.047

# %%
vi_dict[0.99]
# Out:
# {0.001: {'mean_reward': 0.823,
#   'mean_eps': 47.584,
#   'iteration': 105,
#   'time_spent': datetime.timedelta(microseconds=39307),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-06: {'mean_reward': 0.824,
#   'mean_eps': 47.394,
#   'iteration': 305,
#   'time_spent': datetime.timedelta(microseconds=100183),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-09: {'mean_reward': 0.808,
#   'mean_eps': 45.784,
#   'iteration': 504,
#   'time_spent': datetime.timedelta(microseconds=196431),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-12: {'mean_reward': 0.835,
#   'mean_eps': 50.884,
#   'iteration': 704,
#   'time_spent': datetime.timedelta(microseconds=553295),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-15: {'mean_reward': 0.807,
#   'mean_eps': 47.407,
#   'iteration': 903,
#   'time_spent': datetime.timedelta(microseconds=267922),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])}}

# %%
pi_dict[0.9999]
# Out:
# {0.001: {'mean_reward': 0.806,
#   'mean_eps': 48.839,
#   'iteration': 6,
#   'time_spent': datetime.timedelta(microseconds=26932),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-06: {'mean_reward': 0.811,
#   'mean_eps': 47.488,
#   'iteration': 7,
#   'time_spent': datetime.timedelta(microseconds=108449),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-09: {'mean_reward': 0.837,
#   'mean_eps': 50.403,
#   'iteration': 5,
#   'time_spent': datetime.timedelta(microseconds=216246),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-12: {'mean_reward': 0.832,
#   'mean_eps': 50.476,
#   'iteration': 4,
#   'time_spent': datetime.timedelta(microseconds=243903),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-15: {'mean_reward': 0.808,
#   'mean_eps': 49.674,
#   'iteration': 7,
#   'time_spent': datetime.timedelta(microseconds=432666),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])}}

# %%
pol = vi_dict[0.99][1e-12]['policy']
vi4 = convert_dict_to_dict(vi_dict)
see_policy(4, pol)

# %%
plot_the_dict(vi4[0], value="Score", size=4)

# %%
plot_the_dict(vi4[1], value="Iteration", size=4)

# %%
plot_the_dict(vi4[2], value="Time", size=4)

# %%
plot_the_dict(vi4[3], value="Score", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(vi4[4], value="Iteration", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(vi4[5], value="Time", size=4, variable="Log Epsilon Value", log=True)

# %%
pol = pi_dict[0.99][1e-12]['policy']
pi4 = convert_dict_to_dict(pi_dict)
see_policy(4, pol)

# %%
plot_the_dict(pi4[0], value="Score", size=4)

# %%
plot_the_dict(pi4[1], value="Iteration", size=4)

# %%
plot_the_dict(pi4[2], value="Time", size=4)

# %%
plot_the_dict(pi4[3], value="Score", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(pi4[4], value="Iteration", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(pi4[5], value="Time", size=4, variable="Log Epsilon Value", log=True)

# %% [markdown]
# ## 16 x 16

# %%
env = FrozenLakeEnv(desc=MAPS["16x16"])
vi_dict16, pi_dict16 = train_and_test_pi_vi(env, discount=[0.5, 0.75, 0.9, 0.95, 0.99, 0.9999], 
                                          epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], mute=False)
# Out:
# Running Value Iteration - Discount: 0.5, Epsilon: 0.001
# Solved in: 7 episodes and 0:00:00.030611 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 0.001
# Solved in: 7 episodes, Time: 0:00:00.030611
# Mean Reward: 0.0, Mean Episodes: 3.096
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 0.001
# Solved in: 27 episodes and 0:00:00.108073 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 0.001
# Solved in: 27 episodes, Time: 0:00:00.108073
# Mean Reward: 0.148, Mean Episodes: 92.001
#
# Running Value Iteration - Discount: 0.5, Epsilon: 1e-06
# Solved in: 15 episodes and 0:00:00.031035 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 1e-06
# Solved in: 15 episodes, Time: 0:00:00.031035
# Mean Reward: 0.0, Mean Episodes: 2.935
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 1e-06
# Solved in: 25 episodes and 0:00:00.124836 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 1e-06
# Solved in: 25 episodes, Time: 0:00:00.124836
# Mean Reward: 0.13, Mean Episodes: 89.865
#
# Running Value Iteration - Discount: 0.5, Epsilon: 1e-09
# Solved in: 24 episodes and 0:00:00.062498 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 1e-09
# Solved in: 24 episodes, Time: 0:00:00.062498
# Mean Reward: 0.0, Mean Episodes: 2.924
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 1e-09
# Solved in: 12 episodes and 0:00:00.138569 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 1e-09
# Solved in: 12 episodes, Time: 0:00:00.138569
# Mean Reward: 0.175, Mean Episodes: 103.929
#
# Running Value Iteration - Discount: 0.5, Epsilon: 1e-12
# Solved in: 34 episodes and 0:00:00.084009 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 1e-12
# Solved in: 34 episodes, Time: 0:00:00.084009
# Mean Reward: 0.148, Mean Episodes: 95.149
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 1e-12
# Solved in: 7 episodes and 0:00:00.155711 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 1e-12
# Solved in: 7 episodes, Time: 0:00:00.155711
# Mean Reward: 0.151, Mean Episodes: 98.043
#
# Running Value Iteration - Discount: 0.5, Epsilon: 1e-15
# Solved in: 43 episodes and 0:00:00.114254 seconds
# Results - Value Iteration: Discount: 0.5, Epsilon: 1e-15
# Solved in: 43 episodes, Time: 0:00:00.114254
# Mean Reward: 0.136, Mean Episodes: 97.532
#
# Running Policy Iteration - Discount: 0.5, Epsilon: 1e-15
# Solved in: 7 episodes and 0:00:00.184874 seconds
# Results - Policy Iteration: Discount: 0.5, Epsilon: 1e-15
# Solved in: 7 episodes, Time: 0:00:00.184874
# Mean Reward: 0.151, Mean Episodes: 97.755
#
# Running Value Iteration - Discount: 0.75, Epsilon: 0.001
# Solved in: 12 episodes and 0:00:00.030203 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 0.001
# Solved in: 12 episodes, Time: 0:00:00.030203
# Mean Reward: 0.0, Mean Episodes: 2.923
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 0.001
# Solved in: 21 episodes and 0:00:00.106108 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 0.001
# Solved in: 21 episodes, Time: 0:00:00.106108
# Mean Reward: 0.116, Mean Episodes: 78.733
#
# Running Value Iteration - Discount: 0.75, Epsilon: 1e-06
# Solved in: 31 episodes and 0:00:00.112965 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 1e-06
# Solved in: 31 episodes, Time: 0:00:00.112965
# Mean Reward: 0.159, Mean Episodes: 96.678
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 1e-06
# Solved in: 18 episodes and 0:00:00.243209 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 1e-06
# Solved in: 18 episodes, Time: 0:00:00.243209
# Mean Reward: 0.157, Mean Episodes: 91.692
#
# Running Value Iteration - Discount: 0.75, Epsilon: 1e-09
# Solved in: 54 episodes and 0:00:00.155695 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 1e-09
# Solved in: 54 episodes, Time: 0:00:00.155695
# Mean Reward: 0.169, Mean Episodes: 96.095
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 1e-09
# Solved in: 5 episodes and 0:00:00.181091 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 1e-09
# Solved in: 5 episodes, Time: 0:00:00.181091
# Mean Reward: 0.175, Mean Episodes: 102.638
#
# Running Value Iteration - Discount: 0.75, Epsilon: 1e-12
# Solved in: 77 episodes and 0:00:00.225784 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 1e-12
# Solved in: 77 episodes, Time: 0:00:00.225784
# Mean Reward: 0.16, Mean Episodes: 99.366
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 1e-12
# Solved in: 7 episodes and 0:00:00.299021 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 1e-12
# Solved in: 7 episodes, Time: 0:00:00.299021
# Mean Reward: 0.155, Mean Episodes: 99.192
#
# Running Value Iteration - Discount: 0.75, Epsilon: 1e-15
# Solved in: 100 episodes and 0:00:00.301509 seconds
# Results - Value Iteration: Discount: 0.75, Epsilon: 1e-15
# Solved in: 100 episodes, Time: 0:00:00.301509
# Mean Reward: 0.162, Mean Episodes: 96.24
#
# Running Policy Iteration - Discount: 0.75, Epsilon: 1e-15
# Solved in: 7 episodes and 0:00:00.641420 seconds
# Results - Policy Iteration: Discount: 0.75, Epsilon: 1e-15
# Solved in: 7 episodes, Time: 0:00:00.641420
# Mean Reward: 0.154, Mean Episodes: 100.452
#
# Running Value Iteration - Discount: 0.9, Epsilon: 0.001
# Solved in: 20 episodes and 0:00:00.047226 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 0.001
# Solved in: 20 episodes, Time: 0:00:00.047226
# Mean Reward: 0.0, Mean Episodes: 2.911
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 0.001
# Solved in: 21 episodes and 0:00:00.127369 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 0.001
# Solved in: 21 episodes, Time: 0:00:00.127369
# Mean Reward: 0.134, Mean Episodes: 84.337
#
# Running Value Iteration - Discount: 0.9, Epsilon: 1e-06
# Solved in: 77 episodes and 0:00:00.230257 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 1e-06
# Solved in: 77 episodes, Time: 0:00:00.230257
# Mean Reward: 0.258, Mean Episodes: 154.002
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 1e-06
# Solved in: 5 episodes and 0:00:00.233905 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 1e-06
# Solved in: 5 episodes, Time: 0:00:00.233905
# Mean Reward: 0.266, Mean Episodes: 159.42
#
# Running Value Iteration - Discount: 0.9, Epsilon: 1e-09
# Solved in: 138 episodes and 0:00:00.426793 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 1e-09
# Solved in: 138 episodes, Time: 0:00:00.426793
# Mean Reward: 0.257, Mean Episodes: 166.215
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 1e-09
# Solved in: 19 episodes and 0:00:01.476060 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 1e-09
# Solved in: 19 episodes, Time: 0:00:01.476060
# Mean Reward: 0.243, Mean Episodes: 162.423
#
# Running Value Iteration - Discount: 0.9, Epsilon: 1e-12
# Solved in: 199 episodes and 0:00:00.851215 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 1e-12
# Solved in: 199 episodes, Time: 0:00:00.851215
# Mean Reward: 0.24, Mean Episodes: 154.135
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 1e-12
# Solved in: 18 episodes and 0:00:02.167235 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 1e-12
# Solved in: 18 episodes, Time: 0:00:02.167235
# Mean Reward: 0.243, Mean Episodes: 157.947
#
# Running Value Iteration - Discount: 0.9, Epsilon: 1e-15
# Solved in: 260 episodes and 0:00:00.887584 seconds
# Results - Value Iteration: Discount: 0.9, Epsilon: 1e-15
# Solved in: 260 episodes, Time: 0:00:00.887584
# Mean Reward: 0.267, Mean Episodes: 163.239
#
# Running Policy Iteration - Discount: 0.9, Epsilon: 1e-15
# Solved in: 19 episodes and 0:00:02.479766 seconds
# Results - Policy Iteration: Discount: 0.9, Epsilon: 1e-15
# Solved in: 19 episodes, Time: 0:00:02.479766
# Mean Reward: 0.253, Mean Episodes: 154.555
#
# Running Value Iteration - Discount: 0.95, Epsilon: 0.001
# Solved in: 31 episodes and 0:00:00.079671 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 0.001
# Solved in: 31 episodes, Time: 0:00:00.079671
# Mean Reward: 0.15, Mean Episodes: 102.041
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 0.001
# Solved in: 11 episodes and 0:00:00.102780 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 0.001
# Solved in: 11 episodes, Time: 0:00:00.102780
# Mean Reward: 0.132, Mean Episodes: 85.707
#
# Running Value Iteration - Discount: 0.95, Epsilon: 1e-06
# Solved in: 147 episodes and 0:00:00.614758 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 1e-06
# Solved in: 147 episodes, Time: 0:00:00.614758
# Mean Reward: 0.35, Mean Episodes: 196.95
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 1e-06
# Solved in: 5 episodes and 0:00:00.408741 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 1e-06
# Solved in: 5 episodes, Time: 0:00:00.408741
# Mean Reward: 0.364, Mean Episodes: 194.611
#
# Running Value Iteration - Discount: 0.95, Epsilon: 1e-09
# Solved in: 268 episodes and 0:00:00.974021 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 1e-09
# Solved in: 268 episodes, Time: 0:00:00.974021
# Mean Reward: 0.313, Mean Episodes: 195.676
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 1e-09
# Solved in: 18 episodes and 0:00:02.952309 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 1e-09
# Solved in: 18 episodes, Time: 0:00:02.952309
# Mean Reward: 0.335, Mean Episodes: 200.796
#
# Running Value Iteration - Discount: 0.95, Epsilon: 1e-12
# Solved in: 384 episodes and 0:00:01.569207 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 1e-12
# Solved in: 384 episodes, Time: 0:00:01.569207
# Mean Reward: 0.337, Mean Episodes: 193.693
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 1e-12
# Solved in: 19 episodes and 0:00:03.975538 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 1e-12
# Solved in: 19 episodes, Time: 0:00:03.975538
# Mean Reward: 0.341, Mean Episodes: 202.802
#
# Running Value Iteration - Discount: 0.95, Epsilon: 1e-15
# Solved in: 499 episodes and 0:00:02.186034 seconds
# Results - Value Iteration: Discount: 0.95, Epsilon: 1e-15
# Solved in: 499 episodes, Time: 0:00:02.186034
# Mean Reward: 0.34, Mean Episodes: 190.319
#
# Running Policy Iteration - Discount: 0.95, Epsilon: 1e-15
# Solved in: 18 episodes and 0:00:05.383414 seconds
# Results - Policy Iteration: Discount: 0.95, Epsilon: 1e-15
# Solved in: 18 episodes, Time: 0:00:05.383414
# Mean Reward: 0.333, Mean Episodes: 193.895
#
# Running Value Iteration - Discount: 0.99, Epsilon: 0.001
# Solved in: 93 episodes and 0:00:00.276485 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 0.001
# Solved in: 93 episodes, Time: 0:00:00.276485
# Mean Reward: 0.382, Mean Episodes: 206.61
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 0.001
# Solved in: 8 episodes and 0:00:00.235902 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 0.001
# Solved in: 8 episodes, Time: 0:00:00.235902
# Mean Reward: 0.418, Mean Episodes: 234.165
#
# Running Value Iteration - Discount: 0.99, Epsilon: 1e-06
# Solved in: 518 episodes and 0:00:02.049738 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 1e-06
# Solved in: 518 episodes, Time: 0:00:02.049738
# Mean Reward: 0.414, Mean Episodes: 234.916
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 1e-06
# Solved in: 19 episodes and 0:00:02.944690 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 1e-06
# Solved in: 19 episodes, Time: 0:00:02.944690
# Mean Reward: 0.45, Mean Episodes: 235.726
#
# Running Value Iteration - Discount: 0.99, Epsilon: 1e-09
# Solved in: 903 episodes and 0:00:02.478474 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 1e-09
# Solved in: 903 episodes, Time: 0:00:02.478474
# Mean Reward: 0.448, Mean Episodes: 234.724
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 1e-09
# Solved in: 6 episodes and 0:00:03.242839 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 1e-09
# Solved in: 6 episodes, Time: 0:00:03.242839
# Mean Reward: 0.446, Mean Episodes: 240.878
#
# Running Value Iteration - Discount: 0.99, Epsilon: 1e-12
# Solved in: 1287 episodes and 0:00:03.792066 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 1e-12
# Solved in: 1287 episodes, Time: 0:00:03.792066
# Mean Reward: 0.444, Mean Episodes: 240.355
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 1e-12
# Solved in: 5 episodes and 0:00:04.614087 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 1e-12
# Solved in: 5 episodes, Time: 0:00:04.614087
# Mean Reward: 0.431, Mean Episodes: 237.082
#
# Running Value Iteration - Discount: 0.99, Epsilon: 1e-15
# Solved in: 1672 episodes and 0:00:05.255067 seconds
# Results - Value Iteration: Discount: 0.99, Epsilon: 1e-15
# Solved in: 1672 episodes, Time: 0:00:05.255067
# Mean Reward: 0.434, Mean Episodes: 242.207
#
# Running Policy Iteration - Discount: 0.99, Epsilon: 1e-15
# Solved in: 4 episodes and 0:00:04.477439 seconds
# Results - Policy Iteration: Discount: 0.99, Epsilon: 1e-15
# Solved in: 4 episodes, Time: 0:00:04.477439
# Mean Reward: 0.426, Mean Episodes: 242.14
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 0.001
# Solved in: 302 episodes and 0:00:00.917549 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 0.001
# Solved in: 302 episodes, Time: 0:00:00.917549
# Mean Reward: 0.477, Mean Episodes: 275.048
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 0.001
# Solved in: 19 episodes and 0:00:01.039393 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 0.001
# Solved in: 19 episodes, Time: 0:00:01.039393
# Mean Reward: 0.482, Mean Episodes: 289.433
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 1e-06
# Solved in: 1449 episodes and 0:00:05.002631 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 1e-06
# Solved in: 1449 episodes, Time: 0:00:05.002631
# Mean Reward: 0.503, Mean Episodes: 338.956
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 1e-06
# Solved in: 8 episodes and 0:00:03.743658 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 1e-06
# Solved in: 8 episodes, Time: 0:00:03.743658
# Mean Reward: 0.486, Mean Episodes: 334.03
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 1e-09
# Solved in: 2587 episodes and 0:00:08.485226 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 1e-09
# Solved in: 2587 episodes, Time: 0:00:08.485226
# Mean Reward: 0.488, Mean Episodes: 346.163
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 1e-09
# Solved in: 20 episodes and 0:00:29.237672 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 1e-09
# Solved in: 20 episodes, Time: 0:00:29.237672
# Mean Reward: 0.491, Mean Episodes: 335.04
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 1e-12
# Solved in: 3723 episodes and 0:00:12.572304 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 1e-12
# Solved in: 3723 episodes, Time: 0:00:12.572304
# Mean Reward: 0.469, Mean Episodes: 342.016
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 1e-12
# Solved in: 7 episodes and 0:00:14.594862 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 1e-12
# Solved in: 7 episodes, Time: 0:00:14.594862
# Mean Reward: 0.471, Mean Episodes: 338.756
#
# Running Value Iteration - Discount: 0.9999, Epsilon: 1e-15
# Solved in: 4854 episodes and 0:00:15.840575 seconds
# Results - Value Iteration: Discount: 0.9999, Epsilon: 1e-15
# Solved in: 4854 episodes, Time: 0:00:15.840575
# Mean Reward: 0.471, Mean Episodes: 333.902
#
# Running Policy Iteration - Discount: 0.9999, Epsilon: 1e-15
# Solved in: 19 episodes and 0:01:01.066996 seconds
# Results - Policy Iteration: Discount: 0.9999, Epsilon: 1e-15
# Solved in: 19 episodes, Time: 0:01:01.066996
# Mean Reward: 0.479, Mean Episodes: 344.133

# %% [markdown]
# ### Value Iteration Policy

# %%
pol = vi_dict16[0.9999][1e-15]['policy']
vi16 = convert_dict_to_dict(vi_dict16)
see_policy(16, pol)

# %% [markdown]
# ### Policy Iteration Policy

# %%
pol = pi_dict16[0.9999][1e-15]['policy']
see_policy(16, pol)

# %%
plot_the_dict(vi16[0], value="Score", size=16)

# %%
plot_the_dict(vi16[1], value="Iteration", size=16)

# %%
plot_the_dict(vi16[2], value="Time", size=16)

# %%
pi16 = convert_dict_to_dict(pi_dict16)

# %%
plot_the_dict(pi16[0], value="Score", size=16)

# %%
plot_the_dict(pi16[1], value="Iteration", size=16)

# %%
plot_the_dict(pi16[2], value="Time", size=16)
